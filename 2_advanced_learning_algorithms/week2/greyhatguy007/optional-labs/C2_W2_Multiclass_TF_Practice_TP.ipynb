# %% [markdown]
# # Optional Lab - Multi-class Classification

# %% [markdown]
# ## 1.1 Goals
# In this lab, you will explore an example of multi-class classification using neural networks.
#
# <center> <img  src="./images/C2_W2_mclass_header.png" width="600" />    <center/>

# %% [markdown]
# ## 1.2 Tools
# You will use some plotting routines. These are stored in `lab_utils_multiclass_TF.py` in this directory.

# %%
# Kernel crashes half-way through. Found issue by running the codes in python command line 
# https://stackoverflow.com/questions/20554074/sklearn-omp-error-15-initializing-libiomp5md-dll-but-found-mk2iomp5md-dll-a
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib widget
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
np.set_printoptions(precision=2)
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

# %% [markdown]
# # 2.0 Multi-class Classification
# Neural Networks are often used to classify data. Examples are neural networks:
# - take in photos and classify subjects in the photos as {dog,cat,horse,other}
# - take in a sentence and classify the 'parts of speech' of its elements: {noun, verb, adjective etc..}
#
# **A network of this type will have multiple units in its final layer**. Each output is associated with a category. When an input example is applied to the network, the output with the highest value is the category predicted. If the output is applied to a softmax function, **the output of the softmax will provide probabilities of the input being in each category.**
#
# In this lab you will see an example of building a multiclass network in Tensorflow. We will then take a look at how the neural network makes its predictions.
#
# Let's start by creating a four-class data set.

# %% [markdown]
# ## 2.1 Prepare and visualize our data
# We will use Scikit-Learn `make_blobs` function to make a training data set with 4 categories as shown in the plot below.

# %%
# make 4-class dataset for classification
classes = 4
m = 100
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.0
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)
print (X_train.shape, y_train.shape)
print (np.unique(y_train))
# Out:
# (100, 2) (100,)
# [0 1 2 3]

# %%
plt_mc(X_train,y_train,classes, centers, std=std)
# Out:
# <img src="data:image/png;base64,..." width="300">

# %% [markdown]
# Each dot represents a training example. The axis `(x0,x1)` are the inputs and the color represents the class the example is associated with. Once trained, the model will be presented with a new example, `(x0,x1)`, and will predict the class.
#
# While generated, this data set is representative of many real-world classification problems. There are several input features `(x0,...,xn)` and several output categories. The model is trained to use the input features to predict the correct output category.

# %%
# show classes in data set
print(f"unique classes {np.unique(y_train)}")
# show how classes are represented
print(f"class representation {y_train[:10]}") # < Class represented in Sparse format >
# show shapes of our dataset
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %% [markdown]
# ## 2.2 Model
# <img align="Right" src="./images/C2_W2_mclass_lab_network.PNG"  style=" width:450px; padding: 10px 20px ; ">
# This lab will use a 2-layer network as shown.
# <b>Unlike the binary classification networks, this network has four outputs, one for each class</b>. Given an input example, the output with the highest value is the predicted class of the input.
#
# Below is an example of how to construct this network in Tensorflow. Notice the output layer uses a `linear` rather than a `softmax` activation. While it is possible to include the softmax in the output layer, it is more numerically stable if linear outputs are passed to the loss function during training. If the model is used to predict probabilities, the softmax can be applied at that point.

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results
model = Sequential(
    [
        Dense(2, activation = 'relu',   name = "L1"),
        Dense(4, activation = 'linear', name = "L2")
    ]
)

# %% [markdown]
# The statements below compile and train the network. Setting `from_logits=True` as an argument to the loss function specifies that the output activation was linear rather than a softmax.

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X_train,y_train,
    epochs=200
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2643
# Epoch 2/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1640
# Epoch 3/200
# 4/4 [==============================] - 0s 0s/step - loss: 1.1030
# Epoch 4/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0482
# Epoch 5/200
# 4/4 [==============================] - 0s 0s/step - loss: 1.0127
# Epoch 6/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9778
# Epoch 7/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.9443
# Epoch 8/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9080
# Epoch 9/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.8766
# Epoch 10/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8454
# Epoch 11/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.8202
# Epoch 12/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7968
# Epoch 13/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.7822
# Epoch 14/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7614
# Epoch 15/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.7371
# Epoch 16/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7155
# Epoch 17/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.6940
# Epoch 18/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6710
# Epoch 19/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.6474
# Epoch 20/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6215
# Epoch 21/200
# 4/4 [==============================] - 0s 508us/step - loss: 0.5944
# Epoch 22/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5660
# Epoch 23/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.5360
# Epoch 24/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5090
# Epoch 25/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.4783
# Epoch 26/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4506
# Epoch 27/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.4233
# Epoch 28/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3991
# Epoch 29/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.3764
# Epoch 30/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3550
# Epoch 31/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.3357
# Epoch 32/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3176
# Epoch 33/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.3019
# Epoch 34/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2882
# Epoch 35/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.2740
# Epoch 36/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2626
# Epoch 37/200
# 4/4 [==============================] - 0s 348us/step - loss: 0.2516
# Epoch 38/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2412
# Epoch 39/200
# 4/4 [==============================] - 0s 406us/step - loss: 0.2316
# Epoch 40/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2228
# Epoch 41/200
# 4/4 [==============================] - 0s 204us/step - loss: 0.2148
# Epoch 42/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2075
# Epoch 43/200
# 4/4 [==============================] - 0s 356us/step - loss: 0.2000
# Epoch 44/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1928
# Epoch 45/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.1854
# Epoch 46/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1800
# Epoch 47/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.1737
# Epoch 48/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1684
# Epoch 49/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.1628
# Epoch 50/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1576
# Epoch 51/200
# 4/4 [==============================] - 0s 514us/step - loss: 0.1530
# Epoch 52/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1484
# Epoch 53/200
# 4/4 [==============================] - 0s 640us/step - loss: 0.1444
# Epoch 54/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1405
# Epoch 55/200
# 4/4 [==============================] - 0s 396us/step - loss: 0.1365
# Epoch 56/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1321
# Epoch 57/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.1290
# Epoch 58/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.1258
# Epoch 59/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.1232
# Epoch 60/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1200
# Epoch 61/200
# 4/4 [==============================] - 0s 862us/step - loss: 0.1169
# Epoch 62/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1137
# Epoch 63/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1108
# Epoch 64/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1077
# Epoch 65/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.1050
# Epoch 66/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1026
# Epoch 67/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.1005
# Epoch 68/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0984
# Epoch 69/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0963
# Epoch 70/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0941
# Epoch 71/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0921
# Epoch 72/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0899
# Epoch 73/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0879
# Epoch 74/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0860
# Epoch 75/200
# 4/4 [==============================] - 0s 734us/step - loss: 0.0841
# Epoch 76/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0823
# Epoch 77/200
# 4/4 [==============================] - 0s 827us/step - loss: 0.0806
# Epoch 78/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0792
# Epoch 79/200
# 4/4 [==============================] - 0s 730us/step - loss: 0.0777
# Epoch 80/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0761
# Epoch 81/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0748
# Epoch 82/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0735
# Epoch 83/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0721
# Epoch 84/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0708
# Epoch 85/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0697
# Epoch 86/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0687
# Epoch 87/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0676
# Epoch 88/200
# 4/4 [==============================] - 0s 613us/step - loss: 0.0663
# Epoch 89/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0653
# Epoch 90/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0641
# Epoch 91/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0631
# Epoch 92/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0620
# Epoch 93/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0610
# Epoch 94/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0600
# Epoch 95/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0598
# Epoch 96/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0596
# Epoch 97/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0589
# Epoch 98/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0580
# Epoch 99/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0570
# Epoch 100/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0560
# Epoch 101/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0551
# Epoch 102/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0542
# Epoch 103/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0534
# Epoch 104/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0525
# Epoch 105/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0518
# Epoch 106/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0512
# Epoch 107/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0505
# Epoch 108/200
# 4/4 [==============================] - 0s 830us/step - loss: 0.0499
# Epoch 109/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0491
# Epoch 110/200
# 4/4 [==============================] - 0s 381us/step - loss: 0.0483
# Epoch 111/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0476
# Epoch 112/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0469
# Epoch 113/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0462
# Epoch 114/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0456
# Epoch 115/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0450
# Epoch 116/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0444
# Epoch 117/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0440
# Epoch 118/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0436
# Epoch 119/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0431
# Epoch 120/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0424
# Epoch 121/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0418
# Epoch 122/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0413
# Epoch 123/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0407
# Epoch 124/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0405
# Epoch 125/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0400
# Epoch 126/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0395
# Epoch 127/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0390
# Epoch 128/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0384
# Epoch 129/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0379
# Epoch 130/200
# 4/4 [==============================] - 0s 833us/step - loss: 0.0373
# Epoch 131/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0370
# Epoch 132/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0365
# Epoch 133/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0360
# Epoch 134/200
# 4/4 [==============================] - 0s 554us/step - loss: 0.0356
# Epoch 135/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0352
# Epoch 136/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0349
# Epoch 137/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0346
# Epoch 138/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 139/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0339
# Epoch 140/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0335
# Epoch 141/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0332
# Epoch 142/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 143/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0326
# Epoch 144/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0323
# Epoch 145/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0320
# Epoch 146/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0317
# Epoch 147/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0314
# Epoch 148/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0312
# Epoch 149/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0309
# Epoch 150/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0305
# Epoch 151/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0306
# Epoch 152/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0299
# Epoch 153/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0297
# Epoch 154/200
# 4/4 [==============================] - 0s 956us/step - loss: 0.0294
# Epoch 155/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0292
# Epoch 156/200
# 4/4 [==============================] - 0s 701us/step - loss: 0.0290
# Epoch 157/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0288
# Epoch 158/200
# 4/4 [==============================] - 0s 602us/step - loss: 0.0285
# Epoch 159/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0282
# Epoch 160/200
# 4/4 [==============================] - 0s 484us/step - loss: 0.0280
# Epoch 161/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0277
# Epoch 162/200
# 4/4 [==============================] - 0s 585us/step - loss: 0.0275
# Epoch 163/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0273
# Epoch 164/200
# 4/4 [==============================] - 0s 477us/step - loss: 0.0271
# Epoch 165/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0269
# Epoch 166/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 167/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0266
# Epoch 168/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0263
# Epoch 169/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0260
# Epoch 170/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0257
# Epoch 171/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0254
# Epoch 172/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 173/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0249
# Epoch 174/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0247
# Epoch 175/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0245
# Epoch 176/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0242
# Epoch 177/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0241
# Epoch 178/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0239
# Epoch 179/200
# 4/4 [==============================] - 0s 334us/step - loss: 0.0237
# Epoch 180/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0235
# Epoch 181/200
# 4/4 [==============================] - 0s 727us/step - loss: 0.0232
# Epoch 182/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0231
# Epoch 183/200
# 4/4 [==============================] - 0s 617us/step - loss: 0.0228
# Epoch 184/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0227
# Epoch 185/200
# 4/4 [==============================] - 0s 997us/step - loss: 0.0225
# Epoch 186/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0223
# Epoch 187/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0221
# Epoch 188/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0219
# Epoch 189/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0219
# Epoch 190/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0217
# Epoch 191/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0215
# Epoch 192/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0214
# Epoch 193/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0212
# Epoch 194/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0210
# Epoch 195/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0208
# Epoch 196/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0207
# Epoch 197/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0205
# Epoch 198/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0204
# Epoch 199/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0202
# Epoch 200/200
# 4/4 [==============================] - 0s 0s/step - loss: 0.0201

# %% [markdown]
# With the model trained, we can see how the model has classified the training data.

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# <img src="data:image/png;base64,..." width="300">
# 184/184 [==============================] - 0s 795us/step

# %% [markdown]
# Above, **the decision boundaries show how the NN model with softmax outputs has partitioned the input space**.  This very simple model has had no trouble classifying the training data. How did it accomplish this? Let's look at the network in more detail.
#
# Below, we will pull the trained weights from the model and use that to plot the function of each of the network units. Further down, there is a more detailed explanation of the results. You don't need to know these details to successfully use neural networks, but it may be helpful to gain more intuition about how the layers combine to solve a classification problem.

# %%
# gather the trained parameters from the first layer
l1 = model.get_layer("L1")
W1,b1 = l1.get_weights()
print (W1.shape, b1.shape)
# Out:
# (2, 2) (2,)

# %%
# plot the function of the first layer
plt_layer_relu(X_train, y_train.reshape(-1,), W1, b1, classes)
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
# gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2, b2 = l2.get_weights()
print (W2.shape, b2.shape) # W2.shape => (2 input features, 4 neurons in this layer)
# create the 'new features', the training examples after L1 transformation
Xl2 = np.maximum(0, np.dot(X_train,W1) + b1)

plt_output_layer_linear(Xl2, y_train.reshape(-1,), W2, b2, classes,
                        x0_rng = (-0.25,np.amax(Xl2[:,0])), x1_rng = (-0.25,np.amax(Xl2[:,1])))
# Out:
# (2, 4) (4,)
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# ## Explanation
# #### Layer 1
#
# <img align="Right" src="./images/C2_W2_mclass_layer1.png"  style=" width:600px; padding: 10px 20px ; ">
#
# These plots show the **function of Units 0 and 1 in the first layer of the network**. The inputs are ($x_0,x_1$) on the axis. The **output of the unit is represented by the color of the background**. This is indicated by the color bar on the right of each graph. Notice that **since these units are using a ReLu, the outputs do not necessarily fall between 0 and 1 and in this case are greater than 20 at their peaks**.
# **The contour lines in this graph show the transition point between the output, $a^{[1]}_j$ being zero and non-zero**. Recall the graph for a ReLu :<img align="right" src="./images/C2_W2_mclass_relu.png"  style=" width:200px; padding: 10px 20px ; "> The contour line in the graph is the inflection point in the ReLu.
#
# <span style="color:blue"><b>Unit 0 has separated classes 0 and 1 from classes 2 and 3</b></span>. Points to the left of the line (classes 0 and 1) will output zero, while points to the right will output a value greater than zero.
# <span style="color:blue"><b>Unit 1 has separated classes 0 and 2 from classes 1 and 3</b></span>. Points above the line (classes 0 and 2 ) will output a zero, while points below will output a value greater than zero. Let's see how this works out in the next layer!

# %% [markdown]
# #### Layer 2, the output layer
#
# <img align="Right" src="./images/C2_W2_mclass_layer2.png"  style=" width:600px; padding: 10px 20px ; ">
#
# **The dots in these graphs are the training examples translated by the first layer**. <span style="color:blue"><b>One way to think of this is the first layer has created a new set of features for evaluation by the 2nd layer</b></span>. The axes in these plots are the outputs of the previous layer $a^{[1]}_0$ and $a^{[1]}_1$. **As predicted above, classes 0 and 1 (blue and green) have  $a^{[1]}_0 = 0$ while classes 0 and 2 (blue and orange) have $a^{[1]}_1 = 0$.**
# Once again, the intensity of the background color indicates the highest values.
# In this output layer,
# - Unit 0 will produce its maximum value for values near (0,0), where class 0 (blue) has been mapped.
# - Unit 1 produces its highest values in the upper left corner selecting class 1 (green).
# - Unit 2 targets the lower right corner where class 2 (orange) resides.
# - Unit 3 produces its highest values in the upper right selecting our final class (purple).
#
#  <span style="color:purple"><b>One other aspect that is not obvious from the graphs is that the values have been coordinated between the units. It is not sufficient for a unit to produce a maximum value for the class it is selecting for, it must also be the highest value of all the units for points in that class</b></span>. This is done by the implied softmax function that is part of the loss function (`SparseCategoricalCrossEntropy`). Unlike other activation functions, the softmax works across all the outputs.
#
# You can successfully use neural networks without knowing the details of what each unit is up to. Hopefully, this example has provided some intuition about what is happening under the hood.

# %% [markdown]
# ## Congratulations!
# You have learned to build and operate a neural network for multiclass classification.
